# %%
import numpy as np 
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras import models, layers, optimizers

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
val_batch = 10
train_batch = 32
train_datagen = ImageDataGenerator(
        rescale=1./255,
        validation_split=0.30,
        )
train_Data = train_datagen.flow_from_directory(
        "/content/drive/My Drive/flowers",
        target_size=(180, 180),
        batch_size=train_batch,
        class_mode='sparse',
        subset = 'training',
        color_mode = 'rgb',
        shuffle = True,
        )
valid_Data = train_datagen.flow_from_directory(
        "/content/drive/My Drive/flowers",
        target_size=(180, 180),
        batch_size=val_batch,
        class_mode='sparse',
        subset = 'validation',
        color_mode = 'rgb',
        shuffle= True)
# Out:
# Found 3028 images belonging to 5 classes.
# Found 1295 images belonging to 5 classes.

# %%
train_Data.class_indices
# Out:
# {'daisy': 0, 'dandelion': 1, 'rose': 2, 'sunflower': 3, 'tulip': 4}

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout,Flatten
model = Sequential()
model.add(Flatten())
model.add(Dense(10, activation='relu'))
#model.add(layers.Dropout(0.2))
model.add(Dense(8, activation='relu'))
#model.add(layers.Dropout(0.2))
model.add(Dense(6,  activation='relu'))
model.add(Dense(1,  activation='softmax'))
model.compile(optimizer='rmsprop',
loss='categorical_crossentropy',
metrics=['accuracy'])

# %%
model.fit(
          train_Data,
          steps_per_epoch = 50,
          batch_size = train_batch,
          validation_data = valid_Data,
          validation_batch_size= val_batch,
          epochs=20)
# Out:
# Epoch 1/20
# 50/50 [==============================] - 14s 280ms/step - loss: 0.0000e+00 - accuracy: 0.2415 - val_loss: 0.0000e+00 - val_accuracy: 0.2432
# Epoch 2/20
# 50/50 [==============================] - 14s 277ms/step - loss: 0.0000e+00 - accuracy: 0.2434 - val_loss: 0.0000e+00 - val_accuracy: 0.2432
# Epoch 3/20
# 50/50 [==============================] - 14s 272ms/step - loss: 0.0000e+00 - accuracy: 0.2389 - val_loss: 0.0000e+00 - val_accuracy: 0.2432
# Epoch 4/20
# 50/50 [==============================] - 14s 277ms/step - loss: 0.0000e+00 - accuracy: 0.2238 - val_loss: 0.0000e+00 - val_accuracy: 0.2432
# Epoch 5/20
# 50/50 [==============================] - 14s 274ms/step - loss: 0.0000e+00 - accuracy: 0.2403 - val_loss: 0.0000e+00 - val_accuracy: 0.2432
# Epoch 6/20
# 50/50 [==============================] - 14s 277ms/step - loss: 0.0000e+00 - accuracy: 0.2363 - val_loss: 0.0000e+00 - val_accuracy: 0.2432
# Epoch 7/20
# 50/50 [==============================] - 14s 274ms/step - loss: 0.0000e+00 - accuracy: 0.2462 - val_loss: 0.0000e+00 - val_accuracy: 0.2432
# Epoch 8/20
# 50/50 [==============================] - 14s 282ms/step - loss: 0.0000e+00 - accuracy: 0.2655 - val_loss: 0.0000e+00 - val_accuracy: 0.2432
# Epoch 9/20
# 50/50 [==============================] - 14s 286ms/step - loss: 0.0000e+00 - accuracy: 0.2358 - val_loss: 0.0000e+00 - val_accuracy: 0.2432
# Epoch 10/20
# 50/50 [==============================] - 14s 279ms/step - loss: 0.0000e+00 - accuracy: 0.2438 - val_loss: 0.0000e+00 - val_accuracy: 0.2432
# Epoch 11/20
# 50/50 [==============================] - 14s 285ms/step - loss: 0.0000e+00 - accuracy: 0.2364 - val_loss: 0.0000e+00 - val_accuracy: 0.2432
# Epoch 12/20
# 50/50 [==============================] - 14s 280ms/step - loss: 0.0000e+00 - accuracy: 0.2502 - val_loss: 0.0000e+00 - val_accuracy: 0.2432
# Epoch 13/20
# 50/50 [==============================] - 14s 286ms/step - loss: 0.0000e+00 - accuracy: 0.2311 - val_loss: 0.0000e+00 - val_accuracy: 0.2432
# Epoch 14/20
# 50/50 [==============================] - 14s 283ms/step - loss: 0.0000e+00 - accuracy: 0.2391 - val_loss: 0.0000e+00 - val_accuracy: 0.2432
# Epoch 15/20
# 50/50 [==============================] - 14s 282ms/step - loss: 0.0000e+00 - accuracy: 0.2553 - val_loss: 0.0000e+00 - val_accuracy: 0.2432
# Epoch 16/20
# 50/50 [==============================] - 14s 282ms/step - loss: 0.0000e+00 - accuracy: 0.2217 - val_loss: 0.0000e+00 - val_accuracy: 0.2432
# Epoch 17/20
# 50/50 [==============================] - 14s 291ms/step - loss: 0.0000e+00 - accuracy: 0.2117 - val_loss: 0.0000e+00 - val_accuracy: 0.2432
# Epoch 18/20
# 50/50 [==============================] - 14s 283ms/step - loss: 0.0000e+00 - accuracy: 0.2441 - val_loss: 0.0000e+00 - val_accuracy: 0.2432
# Epoch 19/20
# 50/50 [==============================] - 14s 281ms/step - loss: 0.0000e+00 - accuracy: 0.2563 - val_loss: 0.0000e+00 - val_accuracy: 0.2432
# Epoch 20/20
# 50/50 [==============================] - 14s 278ms/step - loss: 0.0000e+00 - accuracy: 0.2567 - val_loss: 0.0000e+00 - val_accuracy: 0.2432
